# %%
import time
import random
 
def my_function():
    my_dict = { 
        'easy': { 
            'accept': {'meaning': 'receive', 'marks': 1},
            'affect': {'meaning': 'influence', 'marks': 1},
            'allowed': {'meaning': 'permitted', 'marks': 1},
            'principle': {'meaning': 'rule', 'marks': 1},
            'quite': {'meaning': 'silent', 'marks': 1}
        },
         'moderate': {
            'abundant': {'meaning': 'plentiful', 'marks': 2},
            'benevolent': {'meaning': 'generous', 'marks': 2},
            'commence': {'meaning': 'to begin', 'marks': 2},
            'diligent': {'meaning': 'hard-working', 'marks': 2},
            'fragrant': {'meaning': 'pleasant smell', 'marks': 2}
        },
        'difficult': {
        'aberration': {'meaning': 'deviation', 'marks': 3},
        'deleterious': {'meaning': 'harmful', 'marks': 3},
        'esoteric': {'meaning': 'obscure', 'marks': 3},
        'fortuitous': {'meaning': 'accidental', 'marks': 3},
        'obfuscate': {'meaning': 'confuse', 'marks': 3}
    }
}
        

level = input("Choose difficulty level (easy, moderate, difficult): ").strip().lower()

if level not in my_dict:
    print("Invalid choice! Please restart and enter a valid level.")
else:
    print(f"\nYou have chosen: {level.upper()} level.\nLet's start the quiz!\n")

    words = list(my_dict[level].items())  
    random.shuffle(words)  

    total_score = 0 

    for word, details in words:
        correct_answer = details['meaning']
        marks = details['marks']  

        print(f"What is the meaning of '{word}'?")
        user_answer = input("Your answer: ").strip().lower()

        if user_answer == correct_answer.lower():
            print(f"✅ Correct! You earned {marks} points.\n")
            total_score += marks  
        else:
            print(f"❌ Wrong! The correct answer is: {correct_answer}\n")

        time.sleep(2)

    print(f"\nQuiz Over! Your total score: {total_score} points.")
my_function()
# Out:
# Choose difficulty level (easy, moderate, difficult):  easy
# You have chosen: EASY level.
# Let's start the quiz!
#
# What is the meaning of 'quite'?
# Your answer:  hh
# ❌ Wrong! The correct answer is: silent
#
# What is the meaning of 'affect'?
# Your answer:  nn
# ❌ Wrong! The correct answer is: influence
#
# What is the meaning of 'principle'?
# Your answer:  qq
# ❌ Wrong! The correct answer is: rule
#
# What is the meaning of 'allowed'?
# Your answer:  ss
# ❌ Wrong! The correct answer is: permitted
#
# What is the meaning of 'accept'?
# Your answer:  ww
# ❌ Wrong! The correct answer is: receive
#
#
# Quiz Over! Your total score: 0 points.

# %%
# !pip install playsound

# %%
import time
import random
from playsound import playsound

# Word dictionary
my_dict = {
    'easy': {
        'accept': {'meaning': 'receive', 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\receive.mp3'},
        'affect': {'meaning': 'influence', 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\influence.mp3'},
        'allowed': {'meaning': 'permitted', 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\permitted.mp3'},
        'principle': {'meaning': 'rule', 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\rule.mp3'},
        'quite': {'meaning': 'silent', 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\silent.mp3'}
    },
    'moderate': {
        'abundant': {'meaning': 'plentiful', 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\pentiful.mp3'},
        'benevolent': {'meaning': 'generous', 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\generous.mp3'},
        'commence': {'meaning': 'to begin', 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\to begin.mp3'},
        'diligent': {'meaning': 'hard-working', 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\abscure.mp3'},
        'fragrant': {'meaning': 'pleasant smell', 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\confuse.mp3'}
    },
    'difficult': {
        'aberration': {'meaning': 'deviation', 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\deviation.mp3'},
        'deleterious': {'meaning': 'harmful', 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\harmful.mp3'},
        'esoteric': {'meaning': 'obscure', 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\obscure.mp3'},
        'fortuitous': {'meaning': 'accidental', 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\accidental.mp3'},
        'obfuscate': {'meaning': 'confuse', 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\confuseas.mp3'}
    }
}

# Phrases dictionary
my_phrases = {
    'easy':{
        "call it a day":{'meaning': "stop working on something", 'marks':1},
        "bite the bullet":{'meaning': "decide to do something unpleasant",'marks':1},
       "once in a blue moon": {'meaning':"very rarely",'marks':1},
       "under the weather":{'meaning': "feeling sick",'marks':1},
           },
    'moderate':{
    "on thin ice":{'meaning': "in a risky situation",'marks':2},
    "to be on fire": {'meaning':"performing exceptionally well",'marks':2},
    "let the cat out of the bag":{'meaning': "reveal a secret",'marks':2},
    "a blessing in disguise":{'meaning': "something bad that turns out to be good",'marks':2},
    },
    'difficult':{
    "to break a leg": {'meaning':"good luck",'marks':3},
    "a piece of cake":{'meaning': "something very easy to do",'marks':3},
    "giving someone a cold shoulder":{'meaning': "ignoring someone",'marks':3},
    "cost an arm and a leg": {'meaning':"very expensive",'marks':3},
    }
}

# Function to learn words
def learn_words(learning_type):
    if learning_type == 'words':
        my_data = my_dict
    elif learning_type == 'phrases':
        my_data = my_phrases
    else:
        print("Invalid learning type.")
        return

    level = input("Choose difficulty level to learn (easy, moderate, difficult): ").strip().lower()

    if level not in my_data:
        print("Invalid choice! Please enter a valid level.\n")
        return  

    print(f"\nYou have chosen to LEARN {level.upper()} words/phrases.\n")
    
    if learning_type == 'words':
        for word, details in my_data[level].items():
            print(f"Word: {word.capitalize()} - Meaning: {details['meaning']}")
            playsound(details['path'])
            time.sleep(2)  
    elif learning_type == 'phrases':
        for phrase, meaning in my_data.items():
            print(f"Phrase: {phrase.capitalize()} - Meaning: {meaning}")
            time.sleep(2)  

    print("\nLearning session completed!\n")

# Function to take a quiz
def take_quiz(learning_type):
    if learning_type == 'words':
        my_data = my_dict
    elif learning_type == 'phrases':
        my_data = my_phrases
    else:
        print("Invalid quiz type.")
        return  

    level = input("Choose difficulty level for the quiz (easy, moderate, difficult): ").strip().lower()

    if level not in my_data:
        print("Invalid choice! Please enter a valid level.\n")
        return  
    
    print(f"\nYou have chosen: {level.upper()} level.\nLet's start the quiz!\n")

    words = list(my_data[level].items()) if learning_type == 'words' else list(my_data.items())
    random.shuffle(words)  

    total_score = 0  

    for item, details in words:
        if learning_type == 'words':
            correct_answer = details['meaning']
            marks = details['marks']  
            print(f"What is the meaning of '{item}'?")
        elif learning_type == 'phrases':
            correct_answer = details
            marks = 1  
            print(f"What does the phrase '{item}' mean?")
        
        user_answer = input("Your answer: ").strip().lower()

        if user_answer == correct_answer.lower():
            print(f"✅ Correct! You earned {marks} points.\n")
            total_score += marks  
        else:
            print(f"❌ Wrong! The correct answer is: {correct_answer}\n")

        time.sleep(2)

    print(f"\nQuiz Over! Your total score: {total_score} points.\n")

# Main function
def main():
    while True:  
        choice = input("Do you want to (1) Learn words, (2) Learn phrases, (3) Take a quiz, or (4) Exit? Enter 1, 2, 3, or 4: ").strip()
        
        if choice == '1':
            learn_words('words')
        elif choice == '2':
            learn_words('phrases')
        elif choice == '3':
            learn_type = input("Do you want to quiz on (1) words or (2) phrases? ").strip()
            if learn_type == '1':
                take_quiz('words')
            elif learn_type == '2':
                take_quiz('phrases')
            else:
                print("Invalid choice! Please enter 1 or 2.\n")
        elif choice == '4':
            print("Goodbye! Thanks for learning and practicing. 😊")
            break  
        else:
            print("Invalid choice! Please enter 1, 2, 3, or 4.\n")

main()
# Out:
# Do you want to (1) Learn words, (2) Learn phrases, (3) Take a quiz, or (4) Exit? Enter 1, 2, 3, or 4:  4
# Goodbye! Thanks for learning and practicing. 😊

# %%
import time
import random
from playsound import playsound
import ipywidgets as widgets
widgets.IntSlider()
from IPython.display import display, clear_output

# === Dictionaries ===
my_dict = {
    'easy': {
        'accept': {'meaning': 'receive', 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\receive.mp3'},
        'affect': {'meaning': 'influence', 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\influence.mp3'},
        'allowed': {'meaning': 'permitted', 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\permitted.mp3'},
        'principle': {'meaning': 'rule', 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\rule.mp3'},
        'quite': {'meaning': 'silent', 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\silent.mp3'}
    },
    'moderate': {
        'abundant': {'meaning': 'plentiful', 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\pentiful.mp3'},
        'benevolent': {'meaning': 'generous', 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\generous.mp3'},
        'commence': {'meaning': 'to begin', 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\to begin.mp3'},
        'diligent': {'meaning': 'hard-working', 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\abscure.mp3'},
        'fragrant': {'meaning': 'pleasant smell', 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\confuse.mp3'}
    },
    'difficult': {
        'aberration': {'meaning': 'deviation', 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\receive.mp3'},
        'deleterious': {'meaning': 'harmful', 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\receive.mp3'},
        'esoteric': {'meaning': 'obscure', 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\receive.mp3'},
        'fortuitous': {'meaning': 'accidental', 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\receive.mp3'},
        'obfuscate': {'meaning': 'confuse', 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\receive.mp3'}
    }
}

my_phrases = {
    'easy': {
        "call it a day": {'meaning': "stop working on something", 'marks': 1},
        "bite the bullet": {'meaning': "decide to do something unpleasant", 'marks': 1},
        "once in a blue moon": {'meaning': "very rarely", 'marks': 1},
        "under the weather": {'meaning': "feeling sick", 'marks': 1},
    },
    'moderate': {
        "on thin ice": {'meaning': "in a risky situation", 'marks': 2},
        "to be on fire": {'meaning': "performing exceptionally well", 'marks': 2},
        "let the cat out of the bag": {'meaning': "reveal a secret", 'marks': 2},
        "a blessing in disguise": {'meaning': "something bad that turns out to be good", 'marks': 2},
    },
    'difficult': {
        "to break a leg": {'meaning': "good luck", 'marks': 3},
        "a piece of cake": {'meaning': "something very easy to do", 'marks': 3},
        "giving someone a cold shoulder": {'meaning': "ignoring someone", 'marks': 3},
        "cost an arm and a leg": {'meaning': "very expensive", 'marks': 3},
    }
}

# === Widgets ===
type_dropdown = widgets.Dropdown(
    options=['words', 'phrases'],
    description='Learn:',
)

level_dropdown = widgets.Dropdown(
    options=['easy', 'moderate', 'difficult'],
    description='Level:',
)

learn_button = widgets.Button(description='Start Learning', button_style='success')
output_area = widgets.Output()

# === Event ===
def on_learn_button_click(b):
    output_area.clear_output()
    with output_area:
        learn_items(type_dropdown.value, level_dropdown.value)

learn_button.on_click(on_learn_button_click)

# === Learning Logic ===
def learn_items(learning_type, level):
    if learning_type == 'words':
        data = my_dict
        if level not in data:
            print("Invalid level.")
            return
        print(f"\n📚 LEARNING {level.upper()} WORDS\n")
        for word, details in data[level].items():
            print(f"🔤 Word: {word.capitalize()} - Meaning: {details['meaning']}")
            sound_button = widgets.Button(description=f"🔊 Play '{word}'")
            path = details['path']
            sound_button.on_click(lambda b, p=path: playsound(p))
            display(sound_button)
            time.sleep(0.5)

    elif learning_type == 'phrases':
        data = my_phrases
        if level not in data:
            print("Invalid level.")
            return
        print(f"\n📘 LEARNING {level.upper()} PHRASES\n")
        for phrase, details in data[level].items():
            print(f"💬 Phrase: {phrase.capitalize()} - Meaning: {details['meaning']}")
            time.sleep(0.5)

    print("\n✅ Learning session completed!\n")

# === Display UI ===
display(type_dropdown, level_dropdown, learn_button, output_area)
# Out:
# Dropdown(description='Learn:', options=('words', 'phrases'), value='words')
# Dropdown(description='Level:', options=('easy', 'moderate', 'difficult'), value='easy')
# Button(button_style='success', description='Start Learning', style=ButtonStyle())
# Output()

# %% [markdown]
# pip install Ipython

# %%
# Out:
# 📋 Welcome to the Language Learning App!
# Please register to continue.
# Enter your full name:  samruddhi
# Enter your email address:  samruddhikohokade2036@gmail.com
# Create a username:  Sam
# Create a password:  Samruddhi@20
# ✅ Thank you, samruddhi! You have successfully registered with username 'Sam'.
#
# 👤 Logged in as: Sam
# Do you want to (1) Learn words, (2) Learn phrases, (3) Take a quiz, or (4) Exit? Enter 1, 2, 3, or 4:  1
# Choose difficulty level to learn (easy, moderate, difficult):  easy
# You have chosen to LEARN EASY words/phrases.
#
# Word: Accept - Meaning: receive
# ▶ Click the audio player below to hear the pronunciation:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Word: Affect - Meaning: influence
# ▶ Click the audio player below to hear the pronunciation:
# ...

# %%
import time
import random
from IPython.display import Audio, display
def register_user():
    print("📋 Welcome to the Language Learning App!")
    print("Please register to continue.\n")

    name = input("Enter your full name: ").strip()
    email = input("Enter your email address: ").strip()
    username = input("Create a username: ").strip()
    password = input("Create a password: ").strip()

    print(f"\n✅ Thank you, {name}! You have successfully registered with username '{username}'.\n")
    return {'name': name, 'email': email, 'username': username}


# Word dictionary
my_dict = {
    'easy': {
        'accept': {'meaning': 'receive', 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\receive.mp3'},
        'affect': {'meaning': 'influence', 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\influence.mp3'},
        'allowed': {'meaning': 'permitted', 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\permitted.mp3'},
        'principle': {'meaning': 'rule', 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\rule.mp3'},
        'quite': {'meaning': 'silent', 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\silent.mp3'}
    },
    'moderate': {
        'abundant': {'meaning': 'plentiful', 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\pentiful.mp3'},
        'benevolent': {'meaning': 'generous', 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\generous.mp3'},
        'commence': {'meaning': 'to begin', 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\to begin.mp3'},
        'diligent': {'meaning': 'hard-working', 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\abscure.mp3'},
        'fragrant': {'meaning': 'pleasant smell', 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\confuse.mp3'}
    },
    'difficult': {
        'aberration': {'meaning': 'deviation', 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\receive.mp3'},
        'deleterious': {'meaning': 'harmful', 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\receive.mp3'},
        'esoteric': {'meaning': 'obscure', 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\receive.mp3'},
        'fortuitous': {'meaning': 'accidental', 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\receive.mp3'},
        'obfuscate': {'meaning': 'confuse', 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\receive.mp3'}
    }
}

# Phrases dictionary
my_phrases = {
    'easy': {
        "call it a day": {'meaning': "stop working on something", 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\stop working on something.mp3'},
        "bite the bullet": {'meaning': "decide to do something unpleasant", 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\decide to do something unpleasent.mp3'},
        "once in a blue moon": {'meaning': "very rarely", 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\very rarely.mp3'},
        "under the weather": {'meaning': "feeling sick", 'marks': 1, 'path': 'C:\\Users\\sudhi\\Downloads\\feeling sick.mp3'},
    },
    'moderate': {
        "on thin ice": {'meaning': "in a risky situation", 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\in a risky situation.mp3'},
        "to be on fire": {'meaning': "performing exceptionally well", 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\performing well.mp3'},
        "let the cat out of the bag": {'meaning': "reveal a secret", 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\reveal a secrete.mp3'},
        "a blessing in disguise": {'meaning': "something bad that turns out to be good", 'marks': 2, 'path': 'C:\\Users\\sudhi\\Downloads\\something bad.mp3'},
    },
    'difficult': {
        "to break a leg": {'meaning': "good luck", 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\good luck.mp3'},
        "a piece of cake": {'meaning': "something very easy to do", 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\something easy.mp3'},
        "giving someone a cold shoulder": {'meaning': "ignoring someone", 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\ignoring someone.mp3'},
        "cost an arm and a leg": {'meaning': "very expensive", 'marks': 3, 'path': 'C:\\Users\\sudhi\\Downloads\\expensive.mp3'},
    }
}

# Function to learn words
def learn_words(learning_type):
    if learning_type == 'words':
        my_data = my_dict
    elif learning_type == 'phrases':
        my_data = my_phrases
    else:
        print("Invalid learning type.")
        return

    level = input("Choose difficulty level to learn (easy, moderate, difficult): ").strip().lower()

    if level not in my_data:
        print("Invalid choice! Please enter a valid level.\n")
        return

    print(f"\nYou have chosen to LEARN {level.upper()} words/phrases.\n")

    if learning_type == 'words':
        for word, details in my_data[level].items():
            print(f"Word: {word.capitalize()} - Meaning: {details['meaning']}")
            print("▶ Click the audio player below to hear the pronunciation:")
            try:
                display(Audio(filename=details['path'], autoplay=False))
            except Exception as e:
                print(f"❌ Error playing sound for {word}: {e}")
            time.sleep(1)
    elif learning_type == 'phrases':
        for phrase, details in my_data[level].items():
            print(f"Phrase: {phrase.capitalize()} - Meaning: {details['meaning']}")
            print("▶ Click the audio player below to hear the pronunciation:")
            try:
                display(Audio(filename=details['path'], autoplay=False))
            except Exception as e:
                print(f"❌ Error playing sound for {word}: {e}")
            time.sleep(1)

    print("\n✅ Learning session completed!\n")

# Function to take a quiz
def take_quiz(learning_type):
    if learning_type == 'words':
        my_data = my_dict
    elif learning_type == 'phrases':
        my_data = my_phrases
    else:
        print("Invalid quiz type.")
        return

    level = input("Choose difficulty level for the quiz (easy, moderate, difficult): ").strip().lower()

    if level not in my_data:
        print("Invalid choice! Please enter a valid level.\n")
        return

    print(f"\nYou have chosen: {level.upper()} level.\nLet's start the quiz!\n")

    words = list(my_data[level].items())
    random.shuffle(words)

    total_score = 0

    for item, details in words:
        if learning_type == 'words':
            correct_answer = details['meaning']
            marks = details['marks']
            print(f"What is the meaning of '{item}'?")
        elif learning_type == 'phrases':
            correct_answer = details['meaning']
            marks = details['marks']
            print(f"What does the phrase '{item}' mean?")

        user_answer = input("Your answer: ").strip().lower()

        if user_answer == correct_answer.lower():
            print(f"✅ Correct! You earned {marks} points.\n")
            total_score += marks
        else:
            print(f"❌ Wrong! The correct answer is: {correct_answer}\n")

        time.sleep(1)

    print(f"\n🎯 Quiz Over! Your total score: {total_score} points.\n")

# Main function
def main():
    user = register_user()
    while True:
        print(f"👤 Logged in as: {user['username']}")
        choice = input("Do you want to (1) Learn words, (2) Learn phrases, (3) Take a quiz, or (4) Exit? Enter 1, 2, 3, or 4: ").strip()

        if choice == '1':
            learn_words('words')
        elif choice == '2':
            learn_words('phrases')
        elif choice == '3':
            learn_type = input("Do you want to quiz on (1) words or (2) phrases? ").strip()
            if learn_type == '1':
                take_quiz('words')
            elif learn_type == '2':
                take_quiz('phrases')
            else:
                print("Invalid choice! Please enter 1 or 2.\n")
        elif choice == '4':
            print("👋 Goodbye! Thanks for learning and practicing. 😊")
            break
        else:
            print("Invalid choice! Please enter 1, 2, 3, or 4.\n")

main()
# Out:
# 📋 Welcome to the Language Learning App!
# Please register to continue.
# Enter your full name:  shraddha pathare
# Enter your email address:  shraddhapatharesp@gmail.com
# Create a username:  shraddha
# Create a password:  abc@123
# ✅ Thank you, shraddha pathare! You have successfully registered with username 'shraddha'.
#
# 👤 Logged in as: shraddha
# Do you want to (1) Learn words, (2) Learn phrases, (3) Take a quiz, or (4) Exit? Enter 1, 2, 3, or 4:  1
# Choose difficulty level to learn (easy, moderate, difficult):  moderate
# You have chosen to LEARN MODERATE words/phrases.
#
# Word: Abundant - Meaning: plentiful
# ▶ Click the audio player below to hear the pronunciation:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# Word: Benevolent - Meaning: generous
# ...
